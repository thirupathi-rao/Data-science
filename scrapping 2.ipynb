# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://myanimelist.net/manga/2"
page=requests.get(url)

# %%
soup=BeautifulSoup(page.text)

# %%
soup.find_all("span",itemprop="genre")
# Out:
# [<span itemprop="genre" style="display:none">Action</span>,
#  <span itemprop="genre" style="display:none">Adventure</span>,
#  <span itemprop="genre" style="display:none">Award Winning</span>,
#  <span itemprop="genre" style="display:none">Drama</span>,
#  <span itemprop="genre" style="display:none">Fantasy</span>,
#  <span itemprop="genre" style="display:none">Horror</span>,
#  <span itemprop="genre" style="display:none">Gore</span>,
#  <span itemprop="genre" style="display:none">Military</span>,
#  <span itemprop="genre" style="display:none">Psychological</span>,
#  <span itemprop="genre" style="display:none">Seinen</span>]

# %%
url = "https://myanimelist.net/manga/2"
page=requests.get(url)
soup=BeautifulSoup(page.text)
for i in soup.find_all("span",itemprop="genre"):
    (i.text)
# Out:
# Action
# Adventure
# Award Winning
# Drama
# Fantasy
# Horror
# Gore
# Military
# Psychological
# Seinen
