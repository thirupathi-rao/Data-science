# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # statistics
#
# it is a mathematical discipline to collect, summarize data. Also, we can say that statistics is a branch of applied mathematics.

# %% [markdown]
# ## Population vs sample
#
# - Population Data:
#
# Population data is the collection of all items of interest which is denoted by ‘N’ and the numbers we obtain when using population are called parameters.
#
# - Sample Data:
#
#
# Sample data is a subset of the population which is denoted by ‘n’ and the numbers we obtain when using sample are called statistics.

# %% [markdown]
# 1. descriptive statistics, which describes the properties of sample and population data
#
#
# 2. inferential statistics, which uses those properties dervied from samples and draw conclusions/ inferences about population using hypothesis testing.

# %% [markdown]
# # Descriptive Statistics

# %% [markdown]
# ![image.png](attachment:abeeb4c8-7930-4a3a-83ac-24b78a83d50b.png)

# %% [markdown]
# <html><center><h1>1. Measures of central tendency </h1></center></html>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
10+20+30+40+50+60+70+80
# Out:
# 360

# %%
360/8
# Out:
# 45.0

# %%
import numpy as np
age= np.array([10,20,30,40,50,60,70,80])
print(np.mean(age)) #age arrays mean
# Out:
# 45.0

# %%
np.array([100000,125000,150000,175000,180000]).mean()
# Out:
# 146000.0

# %%
np.array([100000,125000,150000,175000,10000000]).mean()
# Out:
# 2110000.0

# %% [markdown]
# 1. # create a user defined function for calculating mean without using inbuilt functions
# def my_mean(l):
#     -----
#     ----
#     ----
#     return mean
#
# my_mean([10,20,30,40,50,60,70,80]) --- 45
#
# 2. given a number tell it is amstrong or not
#    eg : 153 --- amrstong
#         120 --- not armstrong
#
# 3. def my_median(l):
#     -----
#     ----
#     ----
#     return median

# %%
# construct a function called as my_mean() 

# my_mean(age) ------ 45

# %% [markdown]
# # weighted mean
# ![image.png](attachment:image.png)

# %%
we= [5,6,7,8,9]
val= [10,20,30,40,50]
res=[]
for i,j in zip(l1,l2):
    res.append(i*j)
res
# Out:
# [50, 120, 210, 320, 450]

# %%
def my_weight_mean(w,l):
    ----
    ----
    ---

eg: my_weight_mean([5,6,7,8,9],[10,20,30,40,50])  --- 32.8

# %%
(50+120+210+320+450)/(5+6+7+8+9)
# Out:
# 32.857142857142854

# %%
marks =np.array([10,20,30,40,50])
weightage_marks = np.array([5,6,7,8,9])
print(np.sum(marks))
avg = np.average(marks,weights=weightage_marks)
mean= np.mean(marks)
print(avg,mean)
# Out:
# 150
# 32.857142857142854 30.0

# %%
marks =np.array([10,20,30,40,50])
print(np.mean(marks))
print(my_mean(marks))
# Out:
# 30.0
# 30.0

# %%
import pandas as pd
df= pd.DataFrame({"marks":np.array([10,20,30,40,50])})
df
# Out:
#    marks
# 0     10
# 1     20
# 2     30
# 3     40
# 4     50

# %%
df['marks'].mean()
# Out:
# 30.0

# %%
nr= 5*10 + 6*20 + 7 *30 + 8 *40 + 9*50
dr= 5+6+7+8+9

nr/dr
# Out:
# 32.857142857142854

# %%
# task: calculate weighted avg using own functions

# %% [markdown]
# # Geometric Mean

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a= np.array([10,20,30,40,50])
b= np.array([1,2,3,4,5])
print(a*b)
print(np.multiply(a,b))
# Out:
# [ 10  40  90 160 250]
# [ 10  40  90 160 250]

# %%
r1= np.prod(a)
r2= a.size
print(r1,r2)
# Out:
# 12000000 5

# %%
np.power(12000000,1/5)
# Out:
# 26.051710846973524

# %%
import scipy.stats as st
st.gmean(a)
# Out:
# 26.051710846973528

# %%
import numpy as np
import pandas as pd
df= pd.DataFrame({"marks":np.array([10,20,30,40,50])})
df
# Out:
#    marks
# 0     10
# 1     20
# 2     30
# 3     40
# 4     50

# %%
n= len(df)

# %%
n= df.shape[0]

# %%
np.power(np.prod(df['marks']),1/n)
# Out:
# 26.051710846973524

# %%
a= df['marks']
a
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: marks, dtype: int32

# %%
from scipy import stats 
stats.gmean(df['marks'])
# Out:
# 26.051710846973528

# %% [markdown]
# # Harmonic Mean

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a= np.array([10,20,302,40,50])
print(np.mean(a))
print(np.median(a))
print(np.sum(1/a))
print(5/np.sum(1/a))
# Out:
# 84.4
# 40.0
# 0.1983112582781457
# 25.212890298881284

# %%
st.hmean([10,20,30,40,50])
# Out:
# 21.8978102189781

# %% [markdown]
# # Why are we moving from mean to median?

# %% [markdown]
# ## income levels of 5 people

# %% [markdown]
# my_income = 175000

# %%
income = np.array([100000,150000,200000,250000,300000])
print(np.mean(income))
# Out:
# 200000.0

# %%
income = np.array([100000,150000,200000,10000000,300000])
print(np.mean(income))
# Out:
# 2150000.0

# %%
# outliers -- very large values or very small values when compared to other points in the dataset
# when larger outliers are there avg/mean will be  high when compared to normal mean
# when small outliers are there avg/mean will be low when compared to normal mean

# whenever outliers are there it is not recommended that we calculate mean/avg it will go to wrong analysis
# then we use median

# %% [markdown]
# # Median
#
# ![image.png](attachment:image.png)

# %%
a= np.array([10,20,30,40,50])
np.median(a)
# Out:
# 30.0

# %%
a= np.array([10,20,30,40,50,60])
np.median(a)
# Out:
# 35.0

# %%
# create user defined funtion of median

# %%
#odd number of values
income = np.array([100000,150000,200000,1000000,300000])
np.median(income)
# Out:
# 200000.0

# %%
#even number of values
income = np.array([100000,150000,200000,1000000,300000,100])
print(np.mean(income))
print(np.median(income))
# Out:
# 291683.3333333333
# 175000.0

# %% [markdown]
# # Mode
#
# value which gets repeated more number of times
# we use it for categorical data

# %%
import pandas as pd
gender= pd.DataFrame(np.array(["male","male","female","female","male","female","female","female"]))
gender.value_counts()
# Out:
# 0
# female    5
# male      3
# Name: count, dtype: int64

# %%
# mode --- highest repeating value
gender= np.array(["male","male","female","female","male","female","female","female"])

# %% [markdown]
# # Trimmed Mean

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
(0.9 + 1.2+ 1.8 + 2.3+3.1+3.4 + 3.7+4.4)/8
# Out:
# 2.6000000000000005

# %% [markdown]
# <html><center><h1>2. Measures of variability/ Spread/ Dispersion</h1></center></html>

# %% [markdown]
# # Range

# %% [markdown]
# ![image.png](attachment:a6eacecf-b9c1-414b-9d41-d24f3da65cfc.png)

# %%
import numpy as np
a=np.array([8,109,62,57,61,3,58,60,62,9,110,61,57,122,58])
a
# Out:
# array([  8, 109,  62,  57,  61,   3,  58,  60,  62,   9, 110,  61,  57,
#        122,  58])

# %%
np.max(a) -np.min(a)
# Out:
# 119

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
a= np.array([1,2,3,4,5])
print(np.var(a)) # by default it will take as pop
# Out:
# 2.0

# %%
import numpy as np
a= np.array([1,2,3,4,5])
print(np.var(a,ddof=1)) # now we are changing it to sample
# Out:
# 2.5

# %%
import pandas as pd
df= pd.DataFrame([1,2,3,4,5],columns=['temp'])
df
# Out:
#    temp
# 0     1
# 1     2
# 2     3
# 3     4
# 4     5

# %%
df['temp'].var() # by default in pandas it will consider it as sample
# Out:
# 2.5

# %%
df['temp'].var(ddof=0) # pop variance
# Out:
# 2.0

# %%
def var(l):
    s=0
    for i in l:
        x= i-np.mean(l)
        s=s + x**2
    print(s/len(l))

# %%
var([10,11,12,13,14])
# Out:
# 2.0

# %%
var([1,10,100,200,300])
# Out:
# 13087.36

# %%
((1-x)**2 + (10-x) **2 + (100-x)**2 + (200-x) **2 + (300-x)**2)/5
# Out:
# 13087.36

# %%
x= (1+10+100+300+200)/5
x
# Out:
# 122.2

# %%
import numpy as np
a=np.array([8,109,62,57,61,3,58,60,62,9,110,61,57,122,58])
np.var(a) # numpy array it is population
# Out:
# 1155.626666666667

# %%
b=np.array([10,0,234,12,45,122,0,180,1,17,155,13,27,66,15])
print(np.var(b))
# Out:
# 5364.16

# %%
# variance less --- distance is less --- spread is less --- they are all consistent(together) to mean
# variance more --- distance is more --- spread is more --- they are all far away from mean

# %%
weight_students=np.array([10,20,30,40,50]) #weights are in kgs
v= np.var(weight_students)
s= np.std(weight_students)
print(v,s)
# Out:
# 200.0 14.142135623730951

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math as m
m.sqrt(v)
# Out:
# 14.142135623730951

# %%
weight_students=np.array([10,20,30,40,50])
np.std(weight_students)
# Out:
# 14.142135623730951

# %% [markdown]
# # MAD -mean absolute Deviation

# %% [markdown]
# ![image.png](attachment:e4f6f44f-de79-4390-800b-6c4cd2790c2d.png)

# %% [markdown]
# # Coefficient of Variation (CV)

# %% [markdown]
# ![image.png](attachment:0a0e961f-7693-4935-b881-0d92054c727d.png)

# %%
a= np.array([10,2000,30,40,500])
np.std(a)
# Out:
# 764.3716373597335

# %%
a= np.array([10,20,30,40,50])
np.std(a)
# Out:
# 14.142135623730951

# %%
14/30
# Out:
# 0.4666666666666667

# %%
764/516
# Out:
# 1.4806201550387597

# %% [markdown]
# # Skewness

# %% [markdown]
# ![image.png](attachment:d9284c7b-8af4-40d7-90c9-32d81fd9a17f.png)

# %% [markdown]
# ![image.png](attachment:7c2a7167-c89d-44b1-b8bf-bec2b816ed50.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
a= np.array([10,20,20,30,30,30,40,40,50])
print(a.mean())
print(np.median(a))
# Out:
# 30.0
# 30.0

# %%
pd.DataFrame(a).mode()
# Out:
#     0
# 0  30

# %%
sns.histplot(a)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.kdeplot(a)
plt.axvline(np.mean(a),color='blue',linestyle='dotted')
plt.axvline(np.mean(a),color='red',linestyle='--')

# %%
sns.kdeplot(a)
# Out:
# <Axes: ylabel='Density'>

# %%
np.array([10,20,20,30,30,30,40,40,50]).mean()
# Out:
# 30.0

# %% [markdown]
# # positively skwed ( mean > median )

# %% [markdown]
# while positively skewed distributions have a longer right tail, which may include larger values (positive outliers), skewness alone doesn't determine the presence of outliers, it only means assymetry. Mean is more means extreme values are on right side and it doesnt mean that those points are always outliers.
#
# Outliers are identified based on their deviation from the bulk of the data, rather than the skewness of the distribution.

# %%
import numpy as np
import pandas as pd
a= np.array([10,20,20,30,30,30,40,40,50,10000000])
print(a.mean())
df= pd.DataFrame({'a':a})
df
# Out:
# 1000027.0
#           a
# 0        10
# 1        20
# 2        20
# 3        30
# 4        30
# 5        30
# 6        40
# 7        40
# 8        50
# 9  10000000

# %%
df['a'].mean()
# Out:
# 1027.0

# %%
df['a'].median()
# mean >median
# Out:
# 30.0

# %%
import seaborn as sns
sns.kdeplot(data=df,x='a')
plt.axvline(np.mean(a),color='red')
plt.axvline(np.median(a),color='blue')

# %%
import seaborn as sns
sns.histplot(data=df,x='a',bins=2)
# Out:
# <Axes: xlabel='a', ylabel='Count'>

# %%
k= np.array([10,20,20,30,30,30,40,40,50,100000])
np.median(k)
# Out:
# 30.0

# %%
df = pd.DataFrame(k,columns=['temp'])
df
# Out:
#      temp
# 0      10
# 1      20
# 2      20
# 3      30
# 4      30
# 5      30
# 6      40
# 7      40
# 8      50
# 9  100000

# %%
df['temp'].skew()
# Out:
# 3.1622768691245464

# %% [markdown]
# # Negatively skwed ( mean < median ) -- smaller value outliers

# %%
np.array([1,2,3,100,200,200,300,300,300,400,400,500]).mean()
# Out:
# 270.1

# %%
k= np.array([-100,100000,200000,200000,300000,300000,300000,400000,400000,500000])
np.median(k)
# Out:
# 300000.0

# %%
df= pd.DataFrame({'k':k})
df
# Out:
#         k
# 0    -100
# 1  100000
# 2  200000
# 3  200000
# 4  300000
# 5  300000
# 6  300000
# 7  400000
# 8  400000
# 9  500000

# %%
df['k'].mean()
# Out:
# 269990.0

# %%
df['k'].median()
# Out:
# 300000.0

# %%
df['k'].skew()
# Out:
# -0.3600573717136907

# %%
sns.kdeplot(df['k'])
plt.axvline(np.mean(k),color='red')
plt.axvline(np.median(k),color='blue')

# %%
k= np.random.randn(10000)

# %%
sns.kdeplot(k)
# Out:
# <Axes: ylabel='Density'>

# %%
from scipy.stats import skewnorm
import matplotlib.pyplot as plt
# generating negatively skewed data
numValues = 10000
maxValue = 100
skewness = -5   

random = skewnorm.rvs(a = skewness,loc=maxValue, size=numValues)  #Skewnorm function

# %%
random
# Out:
# array([99.05271986, 99.46687808, 99.73073409, ..., 99.56843719,
#        99.11856469, 98.71460985])

# %%
sns.kdeplot(random)
plt.axvline(np.mean(random),color='red')
plt.axvline(np.median(random),color='blue')

# %%
random.mean()
# Out:
# 99.23122941773488

# %%
np.median(random)
# Out:
# 99.34318397198744

# %%
sns.histplot(random, color = 'green')
plt.show()

# %% [markdown]
# ![image.png](attachment:8abd1c2b-6175-4428-9d3f-aaed0796ad56.png)

# %% [markdown]
# # Kurtosis

# %% [markdown]
# ![image.png](attachment:8aceebeb-9aea-4894-a5a3-72af5b1d6c46.png)

# %% [markdown]
# ![image.png](attachment:04a19d36-a635-430b-b08b-c024e7cf22b6.png)

# %% [markdown]
# ![image.png](attachment:941dfdcc-05a1-42a8-bf13-111a7b8fa0a8.png)

# %% [markdown]
# **Types of Kurtosis**
#
# **Leptokurtic**: Distribution has heavy tails and a sharp peak, meaning more data points are found in the tails. The kurtosis value is greater than 3.
#
# eg :
#
# Stock Market Returns: Real-world financial returns tend to show leptokurtic behavior due to the presence of extreme price movements.
#
# **Platykurtic**: Distribution has light tails and a flat peak, meaning fewer data points in the tails. The kurtosis value is less than 3.
#
# eg :
#
# employee performance evaluations are designed to follow platkurtic sometimes if we have only few people getting other salaries.
#
# **Mesokurtic**: A normal distribution with a kurtosis value of 3. This is the reference for comparison.
#
# eg :
#
# in an exam all people mostly get same scores in an controlled environment

# %%
import pandas as pd
df= pd.DataFrame({"x":[9.0,5.6,4.9,4.5,6.4,4.5,5.1,4.3,5.3,4.3,5.5,5.6,6.1,5.1,2.0]})
df
# Out:
#       x
# 0   9.0
# 1   5.6
# 2   4.9
# 3   4.5
# 4   6.4
# 5   4.5
# 6   5.1
# 7   4.3
# 8   5.3
# 9   4.3
# 10  5.5
# 11  5.6
# 12  6.1
# 13  5.1
# 14  2.0

# %%
import seaborn as sns
sns.kdeplot(df['x'])
# Out:
# <Axes: xlabel='x', ylabel='Density'>

# %%
df['x'].kurt()
# Out:
# 3.7831908910278074

# %%
import numpy as np
import random
arr= np.random.randn(1000)
print(arr)
# Out:
# [ 1.75525168e+00 -9.20606534e-01 -1.60195061e+00 -4.45733833e-01
#  -5.80125655e-01  7.01702734e-02  1.53585906e+00  2.62386636e-01
#  -4.54424737e-01  1.12483325e+00 -8.04742687e-01 -6.68056723e-03
#   3.83787348e-01  4.95879864e-01  6.24639178e-02 -6.70727324e-01
#   1.96525033e+00 -3.96228541e-01  1.67910806e-01 -1.09080037e+00
#   8.59605899e-01 -1.46731865e+00  3.17385588e-01  1.54799640e-01
#   1.82038084e-01 -6.89287368e-01  8.98677095e-01  6.46127594e-02
#  -1.19391598e+00 -1.90386853e+00 -2.58080284e-01 -1.49006061e+00
#  -1.60355779e-01  6.25429512e-01  4.32943969e-01  2.67926091e-02
#  -5.47998453e-01  1.04983125e+00 -1.78643023e-01 -1.29464171e+00
#   4.71721620e-01  1.11912956e+00  2.41779837e-01  1.22963161e+00
#   3.35801874e-01  7.17879681e-03  1.96198035e+00 -9.46013719e-01
#  -4.41659017e-01  8.90096123e-01 -1.73640458e+00 -7.88760247e-01
#  -5.64627754e-01 -1.52386200e+00 -5.12371006e-02 -1.09304663e-01
# ...

# %%
import pandas as pd
df= pd.DataFrame({"x":arr})
df
# Out:
#             x
# 0    1.755252
# 1   -0.920607
# 2   -1.601951
# 3   -0.445734
# 4   -0.580126
# ..        ...
# 995 -2.028297
# 996  0.858670
# 997 -1.315852
# 998  0.481775
# 999 -1.216398
#
# [1000 rows x 1 columns]

# %%
sns.kdeplot(df['x'])
# Out:
# <Axes: xlabel='x', ylabel='Density'>

# %%
df['x'].kurt()
# Out:
# -0.04437398980964735

# %% [markdown]
# # Probability

# %% [markdown]
# Probability can be defined as the ratio of the number of favorable outcomes to the total number of outcomes of an exprimentr. For an experiment having 'n' number of outcomes, the number of favorable outcomes can be denoted by x. The formula to calculate the probability of an event is as follows.
#
# Probability(Event) = Favorable Outcomes/Total Outcomes = x/n

# %% [markdown]
# # Terminology of Probability Theory
#
#
#
# ## 1. Experiment:
#
# A trial or an operation conducted to produce an outcome is called an experiment.
#
# ## 2. Sample Space:
#
# All the possible outcomes of an experiment together constitute a sample space. For example, the sample space of tossing a coin is {head, tail},
# in throwing a unbiased dice (regular dice)-- sample space -- {1,2,3,4,5,6}
#
# ## 3.Favorable Outcome:
#
# An event that has produced the desired result or expected event is called a favorable outcome. For example, when we roll two dice, the possible/favorable outcomes of getting the sum of numbers on the two dice as 4 are (1,3), (2,2), and (3,1).
#
#
# ## 4.Random Experiment:
#
# An experiment that has a well-defined set of outcomes is called a random experiment. For example, when we toss a coin, we know that we would get ahead or tail, but we are not sure which one will appear.
#
#
#
#
# ## 5. Trial:
#
# A trial denotes doing a random experiment.
#
#
# ## 6.Event:
#
# Its the Subset of Sample Sapce. The total number of outcomes of a random experiment is called an event.
#
# **EG:**
#
# - RANDOM EXPERIMENT/ trail: throwing in the dice roll.
#
# - event : getting prime numbers from it
#
# - SAMPLE SPACE FOR DICE ROLL : {1,2,3,4,5,6}
#
# - EVENT : {2,3,5}
#
# - P(EVENT) = (NUMBER OF FAVOURABLE OUTCOMES FOR AN EVENT) / (SAMPLE SPACE OF RANDOM EXP) = |E| / 6 = 3/6
#
#
#
# ## 7.Equally Likely Events:
#
# Events that have the same chances or probability of occurring are called equally likely events. The outcome of one event is independent of the other. For example, when we toss a coin, there are equal chances of getting a head or a tail.
#
# ## 8.Exhaustive Events:
#
# There are six possible outcomes when rolling a die which is {1, 2, 3, 4, 5, 6}. Now, if we roll a die, one of these six outcomes will definitely occur. Hence, all these six outcomes are exhaustive events. When the set of all outcomes of an event is equal to the sample space, we call it an exhaustive event.
#
# ![image-2.png](attachment:image-2.png)
#
#
# ### EG :
#
#
# let A be the event of getting a prime number,
#
# let B be the event of getting a composite number and
#
# C be the event of getting the number 1 (as 1 is neither prime nor composite and it is one of the possible outcomes)
#
# A = {2, 3, 5}, B = {4, 6}, C = {1}
#
# 1. equally likely events yes or no --- no
# 2. exhuastive events yes or no --- yes
# 3. mutually exclusive events yes or no---yes
#
#
# ## 9.Mutually Exclusive Events:
#
#
# Events that cannot happen simultaneously are called mutually exclusive events. For example, the climate can be either hot or cold. We cannot experience the same weather simultaneously.
#
# ![image.png](attachment:image.png)
#
# above dgm is not equally likely events
# but they are exhaustive events
#
# **Example:**
#
# **Mutually Exclusive Events**
#
# A = getting even number in dice roll
#
#
# B = getting odd number in dice roll
#
# A = {2,4,6}
#
# B = (1,2,3}
#
#
# **Non Mutually Exclusive Events**
#
# A = getting Prime number in dice roll
#
#
# B = getting odd number in dice roll
#
# A = {2,3,5}
#
# B = {1,3,5}

# %% [markdown]
# # Axioms of Probability

# %% [markdown]
# **Probability**
#
# Probability is a real-valued function  P
#   that assigns to each event  A
#   in a sample space  S
#   a number called the probability of the event  A
#  , denoted by  P(A)
#  , such that the following three properties are satisfied:
#
# 1. P(A)≥0 -- probability cannot be negative
#  .
# 2. P(S)=1 -- Probabililty of sample space=1
#
# 3. for every finite collection of mutually exclusive events(disjoint sets). That is, if A1,A2,A3,…,Ak
#  are events and Ai∩Aj=∅
#  for all i≠j
#  then
#
# P(A1∪A2∪A3∪…∪Ak)=P(A1)+P(A2)+P(A3)+…+P(Ak)

# %% [markdown]
# ![image.png](attachment:d3628677-2049-4165-81d3-213e392f23c7.png)

# %% [markdown]
# experiment is throwing two dice
# conducting only one trial
#
# e1 -- prob of sum of numbers on two dice is even
#
# {(1,1),(1,3),(1,5),(2,2),(2,4),(2,6),(3,1),(3,3),(3,5),(4,2),(4,4),(4,6),(5,1),(5,3),(5,5),(6,2),(6,4),(6,6)} - 18/36  - 1/2
#
# e2 -- prob of sum of numbers on two dice is odd
#
# {(1,2),(1,4),(1,6),(2,1),(2,3),(2,5),(3,2),(3,4),(3,6),(4,1),(4,3),(4,5),(5,2),(5,4),(5,6),(6,1),(6,3),(6,5)} - 18/36 - 1/2
#
# p(e1 union e2) = {(1,1),(1,3),(1,5),(2,2),(2,4),(2,6),(3,1),(3,3),(3,5),(4,2),(4,4),(4,6),(5,1),(5,3),(5,5),(6,2),(6,4),(6,6),(1,2),(1,4),(1,6),(2,1),(2,3),(2,5),(3,2),(3,4),(3,6),(4,1),(4,3),(4,5),(5,2),(5,4),(5,6),(6,1),(6,3),(6,5)} = 36/36 - 1

# %%
p(e1) = prob of getting numbers more than 5 --- {6}
p(e2) = prob of getting numbers less than 3 ---{1,2}

s= {1,2,3,4,5,6}
# when events are simply mutually exclusive 
e1 | e2= {1,2,6} = 3/6 =1/2
p(e1 | e2) = p(e1)+p(e2)
LHS= RHS

# %%
p(e1) = prob of getting numbers more than 5 --- {6}
p(e2) = prob of getting numbers less than 3 ---{1,2}
p(e3) = prob of getting numnber between 3 an 5(inclusive) ---{3,4,5}

s= {1,2,3,4,5,6}
# when events are simply mutually exclusive 
# when events are exhuastive
p(e1 | e2 | e3) = p(e1)+p(e2)+p(e3)
# LHS = RHS = 1

# %%
p(e1) = prob of getting odd numbers --- {1,3,5}
p(e2) = prob of getting numbers less than 3 ---{1,2}

s= {1,2,3,4,5,6}
# when events are simply not mutually exclusive 
e1 | e2= {1,2,3,5} = p(LHS) = 4/6
p(RHS) = 3/6 + 2/6 =5/6
LHS != RHS

# %% [markdown]
# events
# -- you are in jail -- dept event
#
# event --
# getting a first prize in a lottery ticket -- dept event
# purchasing a lottery ticket -- indept event
#
# event --
#
# going out -- indept event
# getting into traffic accident -- dept event

# %% [markdown]
# # 1. Dependent Events?
# For events to be considered dependent, one must have an influence over how probable another is. In other words, a dependent event can only occur if another event occurs first.
#
#
# - If you park your vehicle illegally, you’re more likely to get a parking ticket.
# - You must buy a lottery ticket to have a chance at winning; your odds of winning are increased if you buy more than one ticket.
# - Committing a serious crime – such as breaking into someone’s home – increases your odds of getting caught and going to jail.

# %% [markdown]
# # 2. What are Independent Events?
# An event is deemed independent when it isn’t connected to another event, or its probability of happening, or conversely, of not happening.
#
# - Taking an Uber ride and getting a free meal at your favorite restaurant
# - running out of food
# - Finding a dollar on the street and buying a lottery ticket; finding a dollar isn’t dictated by buying a lottery ticket, nor does buying the ticket increase your chances of finding a dollar
# - Growing the perfect tomato
# - owning a cat

# %% [markdown]
# # Types of Probability

# %% [markdown]
# # 1. Marginal Probability--- P(A)
#
# # 2. Joint Probability --- P(A⋂B)
#
# # 3. Conditional Probability --- P(A/B)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <html><center><h1>Random Variable</h1></center></html>

# %% [markdown]
# # Random Variable
#
# A random variable, also known as a stochastic variable, functions in the realm of real values within the entire sample space of an experiment. Imagine the domain as the pool of all possible values applicable to the function. Just as a function processes its domain, a random variable operates on its domain (the experiment’s sample space) and assigns a real value to each event or outcome.

# %% [markdown]
# consider the experiment of tossing two coins. We can define X to be a random variable that measures the number of heads observed in the experiment. The sample set is here:
#
# ![image.png](attachment:image.png)
#
# There are 4 possible outcomes for the experiment, and this is the domain of X. The random variable X takes these 4 outcomes/events and processes them to give different real values. For each outcome, the associated value is shown as:
#
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# 1. Discrete Random Variables
#
# Discrete random variables are random variables, whose range is a countable set. A countable set can be either a finite set or a countably infinite set. For instance, in the above example, X is a discrete variable as its range is a finite set ({0, 1, 2}).
#
# 2. Continuous Random Variables
#
#
# Continuous random variables, on the contrary, have a range in the forms of some interval, bounded or unbounded, of the real line. E.g., Let Y be a random variable that is equal to the height of different people in a given population set. Since the people can have different measures of height (not limited to just natural numbers or any countable set), Y is a continuous variable.
#
# 3. Mixed Random Variables:
#
# mixed random variables are ones that are a mixture of both continuous and discrete variables.

# %% [markdown]
# ![image.png](attachment:9c503ba4-cc10-48f5-baca-161902497443.png)

# %% [markdown]
# # 1. Bernouli Distribution

# %% [markdown]
# ![image.png](attachment:93c29954-12ab-4853-8e17-b439b55cb3c6.png)

# %%
from scipy.stats import bernoulli

# Set the probability of success
p = 0.7

# Generate a random Bernoulli outcome
random_outcome = bernoulli.rvs(p)
print("Random outcome (1=success, 0=failure):", random_outcome)

# Probability mass function for 0 and 1
print("P(X=1):", bernoulli.pmf(1, p))  # should print 0.7
print("P(X=0):", bernoulli.pmf(0, p))  # should print 0.3
# Out:
# Random outcome (1=success, 0=failure): 0
# P(X=1): 0.7
# P(X=0): 0.30000000000000004

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Parameters
p = 0.3  # probability of purchase
k = 100  # number of customers

# Generate a Bernoulli distribution dataset
purchases = np.random.binomial(1, p, k)

# Create a DataFrame
data = pd.DataFrame({
    'Purchase_Made': purchases
})

# Count the frequency of each outcome
purchase_counts = data['Purchase_Made'].value_counts().sort_index()

# Plotting
plt.figure(figsize=(5, 4))
sns.barplot(x=purchase_counts.index, y=purchase_counts.values, palette="viridis",hue=purchase_counts.index)
plt.xlabel('Purchase Made (1 = Yes, 0 = No)')
plt.ylabel('Frequency')
plt.title('Frequency of Purchases in Bernoulli Distribution Dataset')
plt.xticks([0, 1], ['No Purchase', 'Purchase'])
plt.show()

# %% [markdown]
# # 2. Binomial Distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import comb

# Parameters
n = 10  # number of trials (coin tosses)
p = 0.5  # probability of success (getting heads)

# Calculate binomial probabilities
k_values = np.arange(n + 1)  # possible outcomes for heads (0 to 10)
binomial_probabilities = [comb(n, k) * (p ** k) * ((1 - p) ** (n - k)) for k in k_values]
binomial_probabilities
# Out:
# [0.0009765625,
#  0.009765625,
#  0.0439453125,
#  0.1171875,
#  0.205078125,
#  0.24609375,
#  0.205078125,
#  0.1171875,
#  0.0439453125,
#  0.009765625,
#  0.0009765625]

# %%
# Plotting the binomial distribution
plt.figure(figsize=(5,4))
plt.bar(k_values, binomial_probabilities, color='skyblue', edgecolor='black')
plt.xlabel('Number of Heads (k)')
plt.ylabel('Probability')
plt.title('Binomial Distribution: Probability of k Heads in 10 Coin Tosses')
plt.xticks(k_values)  # Mark all integer ticks from 0 to 10
plt.show()

# %%
# Plotting the binomial distribution
plt.figure(figsize=(5,4))
plt.bar(k_values, np.array(binomial_probabilities).cumsum(), color='skyblue', edgecolor='black')
plt.xlabel('Number of Heads (k)')
plt.ylabel('Probability')
plt.title('Binomial Distribution: Probability of k Heads in 10 Coin Tosses')
plt.xticks(k_values)  # Mark all integer ticks from 0 to 10
plt.show()

# %% [markdown]
# # Multinomial Distribution
