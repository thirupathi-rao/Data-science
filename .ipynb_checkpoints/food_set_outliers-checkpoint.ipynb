# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"D:\Downloads\food_data (1).csv")

# %%
df
# Out:
#        GPA  Gender  breakfast  calories_day  coffee  \
# 0      2.4       2          1           NaN       1
# 1    3.654       1          1           3.0       2
# 2      3.3       1          1           4.0       2
# 3      3.2       1          1           3.0       2
# 4      3.5       1          1           2.0       2
# ..     ...     ...        ...           ...     ...
# 122      3       1          1           2.0       2
# 123  3.882       1          1           NaN       1
# 124      3       2          1           4.0       1
# 125    3.9       1          1           NaN       2
# 126    3.9       1          1           NaN       2
#
#                          comfort_food  cuisine eating_changes_coded1  \
# 0                                none      NaN                     1
# 1         chocolate, chips, ice cream      1.0                     2
# 2     frozen yogurt, pizza, fast food      3.0                     3
# ...

# %%
df.columns
# Out:
# Index(['GPA', 'Gender', 'breakfast', 'calories_day', 'coffee', 'comfort_food',
#        'cuisine', 'eating_changes_coded1', 'father_education',
#        'father_profession', 'fav_cuisine', 'fav_cuisine_coded', 'fav_food',
#        'fries', 'fruit_day', 'marital_status', 'mother_education',
#        'mother_profession'],
#       dtype='object')

# %% [markdown]
# i'm taking a cleaned data set which i did in previous data cleaning task

# %%
c_df=pd.read_csv(r"D:\Downloads\food_data_cleaned.csv")

# %%
c_df
# Out:
#        GPA  Gender  breakfast  calories_day  coffee  \
# 0    2.400     2.0          1      3.038462     1.0
# 1    3.654     1.0          1      3.000000     2.0
# 2    3.300     1.0          1      4.000000     2.0
# 3    3.200     1.0          1      3.000000     2.0
# 4    3.500     1.0          1      2.000000     2.0
# ..     ...     ...        ...           ...     ...
# 118  3.500     1.0          1      4.000000     2.0
# 119  3.000     1.0          1      2.000000     2.0
# 120  3.882     1.0          1      3.038462     1.0
# 121  3.000     2.0          1      4.000000     1.0
# 122  3.900     1.0          1      3.038462     2.0
#
#                                 comfort_food  cuisine  eating_changes_coded1  \
# 0                                       none      1.0                      1
# 1                chocolate, chips, ice cream      1.0                      2
# 2            frozen yogurt, pizza, fast food      3.0                      3
# ...

# %%
sns.boxplot(c_df['GPA'])
# Out:
# <Axes: ylabel='GPA'>

# %%
c_df['GPA'].unique()
# Out:
# array([2.4      , 3.654    , 3.3      , 3.2      , 3.5      , 2.25     ,
#        3.8      , 3.904    , 3.4      , 3.6      , 3.1      , 3.4232521,
#        4.       , 2.2      , 3.87     , 3.7      , 3.9      , 2.8      ,
#        3.       , 3.65     , 3.89     , 2.9      , 3.605    , 3.83     ,
#        3.292    , 3.35     , 2.6      , 3.67     , 3.73     , 2.71     ,
#        3.68     , 3.75     , 3.92     , 3.77     , 3.63     , 3.882    ])

# %%
# Removing the outliers
def removeOutliers(data, col):
    Q3 = np.quantile(data[col], 0.75)
    Q1 = np.quantile(data[col], 0.25)
    IQR = Q3 - Q1
    lower_range = Q1 - 1.5 * IQR
    upper_range = Q3 + 1.5 * IQR
    l=[]
    for i in data[col]:
        if i > lower_range and i < upper_range:
            l.append(i)
        else:
            l.append(data[col].median())
    return l

# %%
sns.boxplot(removeOutliers(c_df,"GPA"))
# Out:
# <Axes: >

# %%
c_df['GPA']=removeOutliers(c_df,"GPA")

# %%
sns.boxplot(c_df['calories_day'])
# Out:
# <Axes: ylabel='calories_day'>

# %%
sns.boxplot(removeOutliers(c_df,'calories_day'))
# Out:
# <Axes: >

# %%
df=c_df.copy()

# %%
df['calories_day']=removeOutliers(c_df,'calories_day')

# %%
removeOutliers(df,'calories_day')
# Out:
# [3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0,
#  3.0]

# %%
df['calories_day']=removeOutliers(df,'calories_day')

# %%
sns.boxplot(df['calories_day'])
# Out:
# <Axes: ylabel='calories_day'>

# %%
df
# Out:
#        GPA  Gender  breakfast  calories_day  coffee  \
# 0    3.500     2.0          1           3.0     1.0
# 1    3.654     1.0          1           3.0     2.0
# 2    3.300     1.0          1           3.0     2.0
# 3    3.200     1.0          1           3.0     2.0
# 4    3.500     1.0          1           3.0     2.0
# ..     ...     ...        ...           ...     ...
# 118  3.500     1.0          1           3.0     2.0
# 119  3.000     1.0          1           3.0     2.0
# 120  3.882     1.0          1           3.0     1.0
# 121  3.000     2.0          1           3.0     1.0
# 122  3.900     1.0          1           3.0     2.0
#
#                                 comfort_food  cuisine  eating_changes_coded1  \
# 0                                       none      1.0                      1
# 1                chocolate, chips, ice cream      1.0                      2
# 2            frozen yogurt, pizza, fast food      3.0                      3
# ...
