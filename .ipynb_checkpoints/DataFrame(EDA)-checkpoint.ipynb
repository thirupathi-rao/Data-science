# %% [markdown]
# Daily Task: Understanding Statistical Measures and Dataset Exploration
# Task Objective:
# The objective of this task is to load a dataset and explore it using various statistical and
# exploratory data analysis (EDA) functions like info(), describe(), shape, head(),
# tail(), unique(), nunique(), and accessing specific rows or columns.

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\dtrri\bot\nissan-dataset.csv")

# %%
df
# Out:
#          id           full_name   age      gender          model   color  \
# 0         1      Dominic Applin  42.0        Male          Quest    Mauv
# 1         2         Lenee Eteen  54.0  Polygender        R'nessa  Orange
# 2         3      Kendal Esselin  37.0        Male  March / Micra    Teal
# 3         4  Nehemiah Marvelley  55.0        Male         Gloria   Green
# 4         5    Domenic McGeouch  21.0        Male         Avenir   Khaki
# ...     ...                 ...   ...         ...            ...     ...
# 9995   9996         Mike Wilson  63.0  Polygender           Juke  Yellow
# 9996   9997        Katie Wilson  45.0      Female         Maxima    Gray
# 9997   9998          Jane Davis  27.0      Female           Leaf  Yellow
# 9998   9999         Katie Smith  68.0        Male  March / Micra   Green
# 9999  10000         Katie Smith  69.0        Male  March / Micra   Green
#
#       performance        km  condition     price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           10000 non-null  int64
#  1   full_name    9157 non-null   object
#  2   age          9154 non-null   float64
#  3   gender       9144 non-null   object
#  4   model        9130 non-null   object
#  5   color        9139 non-null   object
#  6   performance  9143 non-null   float64
#  7   km           9141 non-null   float64
#  8   condition    9151 non-null   object
#  9   price        9159 non-null   float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 781.4+ KB

# %%
df.describe()
# Out:
#                 id          age  performance             km          price
# count  10000.00000  9154.000000  9143.000000    9141.000000    9159.000000
# mean    5000.50000    43.041730   197.783332  503033.441418   27365.125341
# std     2886.89568    14.776421   112.779620  284967.128714   13598.200111
# min        1.00000    18.000000     0.000000     808.000000    5000.250000
# 25%     2500.75000    31.000000   101.500000  258002.000000   15956.490000
# 50%     5000.50000    43.000000   196.000000  500903.000000   27296.050000
# 75%     7500.25000    56.000000   296.000000  748421.000000   38370.190000
# max    10000.00000    69.000000   399.000000  999915.000000  223980.330000

# %%
df.describe(include='all')
# Out:
#                  id   full_name          age gender model  color  performance  \
# count   10000.00000        9157  9154.000000   9144  9130   9139  9143.000000
# unique          NaN        1100          NaN      8    70     23          NaN
# top             NaN  John Smith          NaN   Male  Juke  Green          NaN
# freq            NaN         106          NaN   2157   882    896          NaN
# mean     5000.50000         NaN    43.041730    NaN   NaN    NaN   197.783332
# std      2886.89568         NaN    14.776421    NaN   NaN    NaN   112.779620
# min         1.00000         NaN    18.000000    NaN   NaN    NaN     0.000000
# 25%      2500.75000         NaN    31.000000    NaN   NaN    NaN   101.500000
# 50%      5000.50000         NaN    43.000000    NaN   NaN    NaN   196.000000
# 75%      7500.25000         NaN    56.000000    NaN   NaN    NaN   296.000000
# max     10000.00000         NaN    69.000000    NaN   NaN    NaN   399.000000
#
# ...

# %%
len(df)
# Out:
# 10000

# %%
df.shape
# Out:
# (10000, 10)

# %%
df.head()
# Out:
#    id           full_name   age      gender          model   color  \
# 0   1      Dominic Applin  42.0        Male          Quest    Mauv
# 1   2         Lenee Eteen  54.0  Polygender        R'nessa  Orange
# 2   3      Kendal Esselin  37.0        Male  March / Micra    Teal
# 3   4  Nehemiah Marvelley  55.0        Male         Gloria   Green
# 4   5    Domenic McGeouch  21.0        Male         Avenir   Khaki
#
#    performance        km  condition     price
# 0        299.0  509305.0   very bad  40394.91
# 1        109.0  965853.0        old   8687.90
# 2         52.0  380906.0        bad  44705.31
# 3        336.0  573171.0  very good  32889.88
# 4          2.0  809470.0        old   6949.22

# %%
df.tail()
# Out:
#          id     full_name   age      gender          model   color  \
# 9995   9996   Mike Wilson  63.0  Polygender           Juke  Yellow
# 9996   9997  Katie Wilson  45.0      Female         Maxima    Gray
# 9997   9998    Jane Davis  27.0      Female           Leaf  Yellow
# 9998   9999   Katie Smith  68.0        Male  March / Micra   Green
# 9999  10000   Katie Smith  69.0        Male  March / Micra   Green
#
#       performance        km condition     price
# 9995        339.0  715741.0       new  19710.18
# 9996         81.0  786768.0       bad  47797.76
# 9997        130.0   99170.0  very bad  35058.91
# 9998        215.0  640764.0       old  21176.71
# 9999        215.0  640764.0       old  21177.71

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
df.columns
# Out:
# Index(['id', 'full_name', 'age', 'gender', 'model', 'color', 'performance',
#        'km', 'condition', 'price'],
#       dtype='object')

# %%
df.values
# Out:
# array([[1, 'Dominic Applin', 42.0, ..., 509305.0, 'very bad', 40394.91],
#        [2, 'Lenee Eteen', 54.0, ..., 965853.0, 'old', 8687.9],
#        [3, 'Kendal Esselin', 37.0, ..., 380906.0, 'bad', 44705.31],
#        ...,
#        [9998, 'Jane Davis', 27.0, ..., 99170.0, 'very bad', 35058.91],
#        [9999, 'Katie Smith', 68.0, ..., 640764.0, 'old', 21176.71],
#        [10000, 'Katie Smith', 69.0, ..., 640764.0, 'old', 21177.71]],
#       dtype=object)

# %%
df['gender'].unique()
# Out:
# array(['Male', 'Polygender', 'Genderqueer', 'Female', 'Genderfluid',
#        'Agender', 'Bigender', nan, 'Non-binary'], dtype=object)

# %%
df['gender'].nunique()
# Out:
# 8

# %%
df['gender'].value_counts()
# Out:
# gender
# Male           2157
# Female         2031
# Genderfluid    1657
# Polygender     1653
# Non-binary     1604
# Genderqueer      23
# Agender          12
# Bigender          7
# Name: count, dtype: int64

# %%
df[df['gender']=='Male']
# Out:
#          id           full_name   age gender          model   color  \
# 0         1      Dominic Applin  42.0   Male          Quest    Mauv
# 2         3      Kendal Esselin  37.0   Male  March / Micra    Teal
# 3         4  Nehemiah Marvelley  55.0   Male         Gloria   Green
# 4         5    Domenic McGeouch  21.0   Male         Avenir   Khaki
# 5         6    Bancroft Le Port  42.0   Male         Pulsar  Indigo
# ...     ...                 ...   ...    ...            ...     ...
# 9988   9989         Jane Wilson  66.0   Male     Pathfinder   Black
# 9989   9990        John Johnson  57.0   Male          Quest   Black
# 9993   9994         Emily Jones  26.0   Male          Quest   Black
# 9998   9999         Katie Smith  68.0   Male  March / Micra   Green
# 9999  10000         Katie Smith  69.0   Male  March / Micra   Green
#
#       performance        km  condition     price
# 0           299.0  509305.0   very bad  40394.91
# 2            52.0  380906.0        bad  44705.31
# ...

# %%
df[(df['gender']=='Male') & (df['age']==df['age'].max())]
# Out:
#          id       full_name   age gender          model   color  performance  \
# 1329   1330      Alex Jones  69.0   Male         Gloria   Black        313.0
# 2280   2281    Chris Wilson  69.0   Male         Maxima  Silver         89.0
# 3161   3162  David Williams  69.0   Male         Maxima   Black        313.0
# 3265   3266   Chris Johnson  69.0   Male           Juke  Yellow        368.0
# 3483   3484      John Smith  69.0   Male         Altima     Red         66.0
# 3542   3543      Alex Davis  69.0   Male           Juke    Gray        262.0
# 3582   3583     Jane Wilson  69.0   Male         Gloria  Orange         82.0
# 3942   3943   Laura Johnson  69.0   Male     Pathfinder  Silver         39.0
# 4383   4384    Laura Miller  69.0   Male        R'nessa  Purple         92.0
# 5103   5104     Chris Davis  69.0   Male     Pathfinder   Green         13.0
# 5224   5225     Chris Moore  69.0   Male          Quest     Red         99.0
# ...

# %%
df[(df['model']=='Pathfinder') & (df['condition']=='new')]
# Out:
#         id       full_name   age       gender       model   color  \
# 1060  1061  Laura Williams  19.0       Female  Pathfinder    Gray
# 1074  1075     John Taylor  21.0   Polygender  Pathfinder    Blue
# 1196  1197     Alex Wilson  63.0         Male  Pathfinder  Purple
# 1228  1229     David Moore  65.0  Genderfluid  Pathfinder  Yellow
# 1320  1321    Laura Miller  18.0   Polygender  Pathfinder     Red
# ...    ...             ...   ...          ...         ...     ...
# 9796  9797    Chris Miller  56.0         Male  Pathfinder   White
# 9832  9833     John Miller  32.0   Polygender  Pathfinder  Silver
# 9837  9838   Emily Johnson  18.0       Female  Pathfinder    Blue
# 9897  9898      John Jones  31.0   Non-binary  Pathfinder  Yellow
# 9938  9939     Laura Davis  56.0   Non-binary  Pathfinder  Purple
#
#       performance        km condition     price
# 1060        193.0  518640.0       new  49397.51
# 1074        105.0  444855.0       new  23003.25
# ...

# %%
c=df.select_dtypes(include='object')
c
# Out:
#                full_name      gender          model   color  condition
# 0         Dominic Applin        Male          Quest    Mauv   very bad
# 1            Lenee Eteen  Polygender        R'nessa  Orange        old
# 2         Kendal Esselin        Male  March / Micra    Teal        bad
# 3     Nehemiah Marvelley        Male         Gloria   Green  very good
# 4       Domenic McGeouch        Male         Avenir   Khaki        old
# ...                  ...         ...            ...     ...        ...
# 9995         Mike Wilson  Polygender           Juke  Yellow        new
# 9996        Katie Wilson      Female         Maxima    Gray        bad
# 9997          Jane Davis      Female           Leaf  Yellow   very bad
# 9998         Katie Smith        Male  March / Micra   Green        old
# 9999         Katie Smith        Male  March / Micra   Green        old
#
# [10000 rows x 5 columns]

# %%
c=df.select_dtypes(include='object').columns
c
# Out:
# Index(['full_name', 'gender', 'model', 'color', 'condition'], dtype='object')
