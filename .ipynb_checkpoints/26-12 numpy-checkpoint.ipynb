# %%
import matplotlib.pyplot as plt

# %%
a=plt.imread(r"C:\Users\dtrri\bot\wp4279420-avengers-endgame-4k-wallpapers.jpg")
print(a)
# Out:
# [[[ 33  30  77]
#   [ 12   9  56]
#   [  6   3  50]
#   ...
#   [  0   0   0]
#   [  5   5   5]
#   [ 27  27  27]]
#
#  [[ 33  30  77]
#   [ 12   9  56]
#   [  6   3  50]
#   ...
#   [  0   0   0]
#   [  5   5   5]
#   [ 27  27  27]]
#
#  [[ 32  29  76]
#   [ 12   9  56]
#   [  5   2  49]
#   ...
#   [  0   0   0]
#   [  5   5   5]
#   [ 27  27  27]]
#
#  ...
#
#  [[ 24  30  64]
#   [  6  12  46]
#   [  0   6  42]
#   ...
#   [192 195 226]
#   [180 183 216]
#   [174 177 210]]
#
#  [[ 23  29  63]
#   [  5  11  45]
#   [  0   5  41]
#   ...
#   [189 192 223]
#   [183 186 219]
#   [182 185 220]]
#
#  [[ 23  29  63]
#   [  5  11  45]
#   [  0   5  41]
#   ...
#   [189 192 225]
#   [188 191 224]
#   [192 195 230]]]

# %%
plt.imshow(a)

# %%
plt.imshow(a[0:1000,2150:2800])

# %%
plt.imshow(a[0:1000,2150:2800][600:800,150:450])

# %%
plt.imshow(a[0:1000,2150:2800][400:500,:])

# %%
plt.imshow(a[0:1000,2150:2800][400:600,:100])

# %%
plt.imshow(a[0:1000,2150:2800][150:350])

# %%
plt.imshow(a[0:1000,2150:2800][420:600,250:350])

# %%
import numpy as np
b=np.flip(a)
plt.imshow(b)

# %%
b=np.sort(a)
plt.imshow(b)

# %%
b=a.transpose(1,0,2)
plt.imshow(b)

# %%
plt.imshow(np.hstack([a,a]))

# %%
plt.imshow(np.vstack([a,a]))
