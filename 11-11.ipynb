# %%
from IPython import display
display.Image("./Screenshot 2024-11-11 103326.png")

# %%
name= 'string'
print(name)
# Out:
# string

# %%
a,b,c=10,20,30
print(a+b+c)
# Out:
# 60

# %%
radius=7
pie=3.14
area=pie*radius**2
print(area)
# Out:
# 153.86

# %%
age=25
print('age before reassign ',age)
age="twenty five"
print('after reassign',age)
# Out:
# age before reassign  25
# after reassign twenty five

# %%
x=10
y=5
print(f'x and y before swap are {x},{y}')
x,y=y,x
print(f'x and y after swap are {x},{y}')
# Out:
# x and y before swap are 10,5
# x and y after swap are 5,10

# %%
from IPython import display
display.Image("./Screenshot 2024-11-11 105118.png")

# %%
print((8+2)*(10-3)
# Out:
# 70

# %%
num1,num2=15,4
print('quotient is ',num1/num2,'reminder is ',num1%num2)
# Out:
# quotient is  3.75 reminder is  3

# %%
print('5 raised to 3 is =',5**3)
# Out:
# 5 raised to 3 is = 125

# %%
a,b=12,7
print(a>b)
# Out:
# True

# %%
print(100==100.0)
# Out:
# True

# %%
from IPython import display
display.Image("./Screenshot 2024-11-12 110525.png")

# %%
x=True
y=False
print(x and y,x or y)
# Out:
# False True

# %%
num=15
if num==15 and num>10:
    print(num>10)
# Out:
# True

# %%
n1=8
if n1%2==0:
    print("Even")
else:
    print("odd")
# Out:
# Even

# %%
list1=[1,2,3]
list2=[1,2,3]
print(list1 is list2)
print(list1==list2)
# Out:
# False
# True

# %%
x=10
y=x
print(x is y)
# Out:
# True
